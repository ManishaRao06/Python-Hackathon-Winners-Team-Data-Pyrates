# %%
# pip install panda
# pip install matplotlib
# pip install numpy
# pip install seaborn
# pip install colorama

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("HospitalDatabase.xlsx")
df_PA = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "Patients")
df_ED = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "EDVisits")
df_AmbV = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "AmbulatoryVisits")
df_ReAd = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "ReAdmissionRegistry")
df_Dis = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "Discharges")
df_Pro = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "Providers")
df_EDU = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "EDUnique")

# %% [markdown]
# <span style="color:#00008B;"> Qs 41: Find the age prone to get stroke. </span><div

# %%
df_stroke = df_ReAd[['PatientID', 'PrimaryDiagnosis']].loc[df_ReAd.PrimaryDiagnosis == 'Stroke']
df_stroke 
#calculating age
df_age = pd.DataFrame(df_PA.PatientID)
now = pd.Timestamp('now')
df_age ['Age'] = (now - df_PA['DateOfBirth']).astype('<m8[Y]')
df_age .sort_values('Age')
df_strokeAge = df_age.merge(df_stroke , how = 'inner')[['Age','PrimaryDiagnosis']]
#df_strokeAge ['AgeRange'] = pd.cut(x=df_strokeAge ['Age'], bins=[35, 45, 55, 65])
df_strokeAge  = df_strokeAge .groupby('Age')['PrimaryDiagnosis'].count().sort_values(ascending = False)
df_strokeAge 
print('The age', df_strokeAge.index[0], 'prone to stroke')
# Out:
# The age 58.0 prone to stroke

# %% [markdown]
# <span style="color:#00008B;"> Qs 42: Calculate mortality by diagnosis. </span>

# %%
mortalitycount = df_Dis[['DischargeDisposition', 'PrimaryDiagnosis']].loc[df_Dis.DischargeDisposition == 'Expired'].groupby('PrimaryDiagnosis').count() 
mortalitycount
patient_count = len(df_Dis)
patient_count
mortality_diagnosis = mortalitycount/patient_count
print(mortality_diagnosis)
# Out:
#                     DischargeDisposition
# PrimaryDiagnosis
# AMI                             0.008333
# Afib                            0.005556
# Broken Leg                      0.004167
# Diabetes                        0.012500
# Fever                           0.005556
# Flu                             0.015278
# Heart Failure                   0.022222
# Hip Fracture                    0.004167
# Hypertension                    0.022222
# Kidney Failure                  0.002778
# Knee Replacement                0.002778
# Laceration                      0.002778
# Pain                            0.001389
# Pneumonia                       0.022222
# Spinal Cord Injury              0.002778
# Stroke                          0.009722

# %% [markdown]
# <span style="color:#00008B;"> Qs 43: Details of the patients whose firstname or lastname contains string "lau" , should be case insensitive. </span>

# %%
df_PA['FL'] = df_PA['FirstName'].str.contains('lau',case=False)| df_PA['LastName'].str.contains('lau',case=False)
(df_PA[(df_PA['FL']==True)])
# Out:
#      PatientID FirstName   LastName             DateOfBirth  Gender  \
# 282      283.0    Lauren     Gaskal 1962-05-08 01:54:00.111  Female
# 322      323.0    Lauren      Foort 1960-06-23 20:07:53.045  Female
# 369      370.0    Zulauf  Ellingham 1982-12-17 16:27:56.391  Female
# 382      383.0    Zulauf        LLC 1969-03-16 07:48:49.338  Female
# 454      455.0    Zulauf      Alvar 1961-10-02 08:24:17.334  Female
# 463      464.0    Zulauf     Manske 1965-06-22 02:49:28.667  Female
# 818      819.0    Zulauf   Bitcheno 1967-04-02 07:17:53.635  Female
# 830      831.0    Zulauf  O'Shavlan 1970-05-17 08:09:28.988  Female
# 850      851.0     Lemmy    Klausen 1973-06-18 06:19:43.475  Female
# 906      907.0  Jerrilyn    Klausen 1979-09-04 13:05:57.870    Male
# 910      911.0    Zulauf     Orbine 1973-06-26 03:13:50.449    Male
#
#                        Race Language    FL
# 282  Black/African-American  English  True
# 322                   White  English  True
# 369                   White  English  True
# 382                   White  English  True
# 454                   White  English  True
# 463                   White  English  True
# 818                   White  English  True
# 830                   White  English  True
# 850                   White  English  True
# 906  Black/African-American  English  True
# 910  Black/African-American  English  True

# %% [markdown]
# <span style="color:#00008B;"> Qs 44: Display data by splitting age in 4 quartiles and labeling the quartiles. </span>

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py
age_quant= pd. DataFrame()
now = pd.Timestamp('now')
age_quant['Age'] = (now - pd.to_datetime(df_PA['DateOfBirth'], format='%m%d%y')).astype('<m8[Y]')
age_quant
age_quant1 = age_quant.quantile([.25, .5, .75 , 1.00])
print(age_quant1)

split_quantiles = np.array(age_quant1)    
  
sm.qqplot(split_quantiles)
py.show()
# Out:
#        Age
# 0.25  43.0
# 0.50  49.0
# 0.75  56.0
# 1.00  63.0

# %% [markdown]
# <span style="color:#00008B;"> Qs 45: Usage of Enumeration in Python with any example. </span>

# %%
for ind, column in enumerate(df_ED['ReasonForVisit']):
    print(ind, column)
# Out:
# 0 Stomach Ache
# 1 Migraine
# 2 Stomach Ache
# 3 Migraine
# 4 Chest Pain
# 5 Bleeding
# 6 Chest Pain
# 7 Car Accident
# 8 Chest Pain
# 9 Chest Pain
# 10 Chest Pain
# 11 Pneumonia
# 12 Pneumonia
# 13 Pneumonia
# 14 Pneumonia
# 15 Fever
# 16 Pneumonia
# 17 Shortness of Breath
# 18 Shortness of Breath
# 19 Fever
# 20 Gun Shot
# 21 Pneumonia
# 22 Shortness of Breath
# 23 Migraine
# 24 Pneumonia
# 25 Pneumonia
# 26 Pneumonia
# 27 Accident
# 28 Chest Pain
# 29 Fever
# 30 Accident
# 31 Accident
# 32 Shortness of Breath
# 33 Shortness of Breath
# 34 Fever
# 35 Shortness of Breath
# 36 Car Accident
# 37 Gun Shot
# 38 Chest Pain
# 39 Pneumonia
# 40 Chest Pain
# 41 Fever
# 42 Shortness of Breath
# 43 Shortness of Breath
# 44 Shortness of Breath
# 45 Stomach Ache
# 46 Migraine
# 47 Stomach Ache
# 48 Migraine
# 49 Chest Pain
# 50 Bleeding
# 51 Chest Pain
# 52 Car Accident
# 53 Chest Pain
# 54 Chest Pain
# 55 Chest Pain
# 56 Pneumonia
# 57 Pneumonia
# 58 Pneumonia
# 59 Pneumonia
# 60 Fever
# 61 Pneumonia
# 62 Shortness of Breath
# 63 Shortness of Breath
# 64 Fever
# 65 Gun Shot
# 66 Pneumonia
# 67 Shortness of Breath
# 68 Migraine
# 69 Pneumonia
# 70 Pneumonia
# 71 Pneumonia
# 72 Accident
# 73 Chest Pain
# 74 Fever
# 75 Accident
# 76 Accident
# 77 Shortness of Breath
# 78 Shortness of Breath
# 79 Stomach Ache
# 80 Migraine
# 81 Stomach Ache
# 82 Migraine
# 83 Chest Pain
# 84 Bleeding
# 85 Chest Pain
# 86 Car Accident
# 87 Chest Pain
# 88 Chest Pain
# 89 Chest Pain
# 90 Pneumonia
# 91 Pneumonia
# 92 Pneumonia
# 93 Pneumonia
# 94 Fever
# 95 Pneumonia
# 96 Shortness of Breath
# 97 Shortness of Breath
# 98 Fever
# 99 Gun Shot
# 100 Pneumonia
# 101 Shortness of Breath
# 102 Migraine
# 103 Pneumonia
# 104 Pneumonia
# 105 Pneumonia
# 106 Accident
# 107 Chest Pain
# 108 Fever
# 109 Accident
# 110 Accident
# 111 Shortness of Breath
# 112 Shortness of Breath
# 113 Stomach Ache
# 114 Migraine
# 115 Stomach Ache
# 116 Migraine
# 117 Chest Pain
# 118 Bleeding
# 119 Chest Pain
# 120 Car Accident
# 121 Chest Pain
# 122 Chest Pain
# 123 Chest Pain
# 124 Pneumonia
# 125 Pneumonia
# 126 Pneumonia
# 127 Pneumonia
# 128 Fever
# 129 Pneumonia
# 130 Shortness of Breath
# 131 Shortness of Breath
# 132 Fever
# 133 Gun Shot
# 134 Pneumonia
# 135 Shortness of Breath
# 136 Migraine
# 137 Pneumonia
# 138 Pneumonia
# 139 Pneumonia
# 140 Accident
# 141 Chest Pain
# 142 Fever
# 143 Accident
# 144 Accident
# 145 Shortness of Breath
# 146 Shortness of Breath
# 147 Stomach Ache
# 148 Migraine
# 149 Stomach Ache
# 150 Migraine
# 151 Chest Pain
# 152 Bleeding
# 153 Chest Pain
# 154 Car Accident
# 155 Chest Pain
# 156 Chest Pain
# 157 Chest Pain
# 158 Pneumonia
# 159 Pneumonia
# 160 Pneumonia
# 161 Pneumonia
# 162 Fever
# 163 Pneumonia
# 164 Shortness of Breath
# 165 Shortness of Breath
# 166 Fever
# 167 Gun Shot
# 168 Pneumonia
# 169 Shortness of Breath
# 170 Migraine
# 171 Pneumonia
# 172 Pneumonia
# 173 Pneumonia
# 174 Accident
# 175 Chest Pain
# 176 Fever
# 177 Accident
# 178 Accident
# 179 Shortness of Breath
# 180 Shortness of Breath
# 181 Stomach Ache
# 182 Migraine
# 183 Stomach Ache
# 184 Migraine
# 185 Chest Pain
# 186 Bleeding
# 187 Chest Pain
# 188 Car Accident
# 189 Chest Pain
# 190 Chest Pain
# 191 Chest Pain
# 192 Pneumonia
# 193 Pneumonia
# 194 Pneumonia
# 195 Pneumonia
# 196 Fever
# 197 Pneumonia
# 198 Shortness of Breath
# 199 Shortness of Breath
# 200 Fever
# 201 Gun Shot
# 202 Pneumonia
# 203 Shortness of Breath
# 204 Migraine
# 205 Pneumonia
# 206 Pneumonia
# 207 Pneumonia
# 208 Accident
# 209 Chest Pain
# 210 Stomach Ache
# 211 Migraine
# 212 Stomach Ache
# 213 Migraine
# 214 Chest Pain
# 215 Bleeding
# 216 Chest Pain
# 217 Car Accident
# 218 Chest Pain
# 219 Chest Pain
# 220 Chest Pain
# 221 Pneumonia
# 222 Pneumonia
# 223 Pneumonia
# 224 Pneumonia
# 225 Fever
# 226 Pneumonia
# 227 Shortness of Breath
# 228 Shortness of Breath
# 229 Fever
# 230 Gun Shot
# 231 Pneumonia
# 232 Shortness of Breath
# 233 Migraine
# 234 Pneumonia
# 235 Pneumonia
# 236 Pneumonia
# 237 Accident
# 238 Chest Pain
# 239 Fever
# 240 Accident
# 241 Accident
# 242 Shortness of Breath
# 243 Shortness of Breath
# 244 Stomach Ache
# 245 Migraine
# 246 Stomach Ache
# 247 Migraine
# 248 Chest Pain
# 249 Bleeding
# 250 Chest Pain
# 251 Car Accident
# 252 Chest Pain
# 253 Chest Pain
# 254 Chest Pain
# 255 Pneumonia
# 256 Pneumonia
# 257 Pneumonia
# 258 Pneumonia
# 259 Fever
# 260 Pneumonia
# 261 Shortness of Breath
# 262 Shortness of Breath
# 263 Fever
# 264 Gun Shot
# 265 Pneumonia
# 266 Shortness of Breath
# 267 Migraine
# 268 Pneumonia
# 269 Pneumonia
# 270 Pneumonia
# 271 Accident
# 272 Chest Pain
# 273 Fever
# 274 Accident
# 275 Accident
# 276 Stomach Ache
# 277 Migraine
# 278 Stomach Ache
# 279 Migraine
# 280 Chest Pain
# 281 Bleeding
# 282 Chest Pain
# 283 Car Accident
# 284 Chest Pain
# 285 Chest Pain
# 286 Chest Pain
# 287 Pneumonia
# 288 Pneumonia
# 289 Pneumonia
# 290 Pneumonia
# 291 Fever
# 292 Pneumonia
# 293 Shortness of Breath
# 294 Shortness of Breath
# 295 Fever
# 296 Gun Shot
# 297 Pneumonia
# 298 Shortness of Breath
# 299 Migraine
# 300 Pneumonia
# 301 Pneumonia
# 302 Pneumonia
# 303 Accident
# 304 Chest Pain
# 305 Fever
# 306 Stomach Ache
# 307 Migraine
# 308 Stomach Ache
# 309 Migraine
# 310 Chest Pain
# 311 Bleeding
# 312 Chest Pain
# 313 Car Accident
# 314 Chest Pain
# 315 Chest Pain
# 316 Chest Pain
# 317 Pneumonia
# 318 Pneumonia
# 319 Pneumonia
# 320 Pneumonia
# 321 Fever
# 322 Pneumonia
# 323 Shortness of Breath
# 324 Shortness of Breath
# 325 Fever
# 326 Gun Shot
# 327 Pneumonia
# 328 Shortness of Breath
# 329 Migraine
# 330 Pneumonia
# 331 Pneumonia
# 332 Pneumonia
# 333 Accident
# 334 Chest Pain
# 335 Fever
# 336 Accident
# 337 Accident
# 338 Shortness of Breath
# 339 Shortness of Breath
# 340 Stomach Ache
# 341 Migraine
# 342 Stomach Ache
# 343 Migraine
# 344 Chest Pain
# 345 Bleeding
# 346 Chest Pain
# 347 Car Accident
# 348 Chest Pain
# 349 Chest Pain
# 350 Chest Pain
# 351 Pneumonia
# 352 Pneumonia
# 353 Pneumonia
# 354 Pneumonia
# 355 Fever
# 356 Pneumonia
# 357 Shortness of Breath
# 358 Shortness of Breath
# 359 Fever
# 360 Gun Shot
# 361 Pneumonia
# 362 Shortness of Breath
# 363 Migraine
# 364 Pneumonia
# 365 Pneumonia
# 366 Pneumonia
# 367 Accident
# 368 Chest Pain
# 369 Fever
# 370 Stomach Ache
# 371 Migraine
# 372 Stomach Ache
# 373 Migraine
# 374 Chest Pain
# 375 Bleeding
# 376 Chest Pain
# 377 Car Accident
# 378 Chest Pain
# 379 Chest Pain
# 380 Chest Pain
# 381 Pneumonia
# 382 Pneumonia
# 383 Pneumonia
# 384 Pneumonia
# 385 Fever
# 386 Pneumonia
# 387 Shortness of Breath
# 388 Shortness of Breath
# 389 Fever
# 390 Gun Shot
# 391 Pneumonia
# 392 Shortness of Breath
# 393 Migraine
# 394 Pneumonia
# 395 Pneumonia
# 396 Pneumonia
# 397 Accident
# 398 Chest Pain
# 399 Fever
# 400 Accident
# 401 Accident
# 402 Shortness of Breath
# 403 Stomach Ache
# 404 Migraine
# 405 Stomach Ache
# 406 Migraine
# 407 Chest Pain
# 408 Bleeding
# 409 Chest Pain
# 410 Car Accident
# 411 Chest Pain
# 412 Chest Pain
# 413 Chest Pain
# 414 Pneumonia
# 415 Pneumonia
# 416 Pneumonia
# 417 Pneumonia
# 418 Fever
# 419 Pneumonia
# 420 Shortness of Breath
# 421 Shortness of Breath
# 422 Fever
# 423 Gun Shot
# 424 Pneumonia
# 425 Shortness of Breath
# 426 Migraine
# 427 Pneumonia
# 428 Pneumonia
# 429 Pneumonia
# 430 Accident
# 431 Chest Pain
# 432 Fever
# 433 Stomach Ache
# 434 Migraine
# 435 Stomach Ache
# 436 Migraine
# 437 Chest Pain
# 438 Bleeding
# 439 Chest Pain
# 440 Car Accident
# 441 Chest Pain
# 442 Chest Pain
# 443 Chest Pain
# 444 Pneumonia
# 445 Pneumonia
# 446 Pneumonia
# 447 Pneumonia
# 448 Fever
# 449 Pneumonia
# 450 Shortness of Breath
# 451 Shortness of Breath
# 452 Fever
# 453 Gun Shot
# 454 Pneumonia
# 455 Shortness of Breath
# 456 Migraine
# 457 Pneumonia
# 458 Pneumonia
# 459 Pneumonia
# 460 Accident
# 461 Chest Pain
# 462 Fever
# 463 Accident
# 464 Accident
# 465 Shortness of Breath
# 466 Shortness of Breath
# 467 Stomach Ache
# 468 Migraine
# 469 Stomach Ache
# 470 Migraine
# 471 Chest Pain
# 472 Bleeding
# 473 Chest Pain
# 474 Car Accident
# 475 Stomach Ache
# 476 Migraine
# 477 Stomach Ache
# 478 Migraine
# 479 Chest Pain
# 480 Bleeding
# 481 Chest Pain
# 482 Car Accident
# 483 Chest Pain
# 484 Chest Pain
# 485 Chest Pain
# 486 Pneumonia
# 487 Pneumonia
# 488 Pneumonia
# 489 Pneumonia
# 490 Fever
# 491 Pneumonia
# 492 Shortness of Breath
# 493 Shortness of Breath
# 494 Fever
# 495 Gun Shot
# 496 Pneumonia
# 497 Shortness of Breath
# 498 Migraine
# 499 Pneumonia
# 500 Pneumonia
# 501 Pneumonia
# 502 Accident
# 503 Chest Pain
# 504 Fever
# 505 Accident
# 506 Accident
# 507 Shortness of Breath
# 508 Shortness of Breath
# 509 Accident
# 510 Shortness of Breath
# 511 Accident
# 512 Shortness of Breath
# 513 Shortness of Breath
# 514 Shortness of Breath
# 515 Migraine
# 516 Pneumonia
# 517 Fever
# 518 Fever
# 519 Fever
# 520 Stomach Ache
# 521 Migraine
# 522 Stomach Ache
# 523 Migraine
# 524 Stomach Ache
# 525 Bleeding
# 526 Fever
# 527 Fever
# 528 Fever
# 529 Fever
# 530 Laceration
# 531 Laceration
# 532 Shortness of Breath
# 533 Shortness of Breath
# 534 Fever
# 535 Stomach Ache
# 536 Migraine
# 537 Shortness of Breath
# 538 Shortness of Breath
# 539 Fever
# 540 Shortness of Breath
# 541 Fever
# 542 Stomach Ache
# 543 Migraine
# 544 Stomach Ache
# 545 Migraine
# 546 Intoxication
# 547 Intoxication
# 548 Fever
# 549 Stomach Ache
# 550 Migraine
# 551 Stomach Ache
# 552 Stomach Ache
# 553 Stomach Ache
# 554 Fever
# 555 Chest Pain
# 556 Pneumonia
# 557 Pneumonia
# 558 Pneumonia
# 559 Pneumonia
# 560 Fever
# 561 Fever
# 562 Pneumonia
# 563 Fever
# 564 Fever
# 565 Shortness of Breath
# 566 Fever
# 567 Cough
# 568 Shortness of Breath
# 569 Stomach Ache
# 570 Migraine
# 571 Migraine
# 572 Pneumonia
# 573 Fever
# 574 Fever
# 575 Fever
# 576 Stomach Ache
# 577 Migraine
# 578 Stomach Ache
# 579 Migraine
# 580 Stomach Ache
# 581 Bleeding
# 582 Fever
# 583 Fever
# 584 Fever
# 585 Fever
# 586 Laceration
# 587 Laceration
# 588 Shortness of Breath
# 589 Shortness of Breath
# 590 Fever
# 591 Stomach Ache
# 592 Migraine
# 593 Shortness of Breath
# 594 Shortness of Breath
# 595 Fever
# 596 Shortness of Breath
# 597 Fever
# 598 Stomach Ache
# 599 Migraine
# 600 Stomach Ache
# 601 Migraine
# 602 Intoxication
# 603 Intoxication
# 604 Fever
# 605 Stomach Ache
# 606 Migraine
# 607 Stomach Ache
# 608 Stomach Ache
# 609 Stomach Ache
# 610 Fever
# 611 Chest Pain
# 612 Pneumonia
# 613 Pneumonia
# 614 Pneumonia
# 615 Pneumonia
# 616 Migraine
# 617 Pneumonia
# 618 Fever
# 619 Fever
# 620 Fever
# 621 Stomach Ache
# 622 Migraine
# 623 Stomach Ache
# 624 Migraine
# 625 Stomach Ache
# 626 Bleeding
# 627 Fever
# 628 Fever
# 629 Fever
# 630 Fever
# 631 Laceration
# 632 Laceration
# 633 Shortness of Breath
# 634 Shortness of Breath
# 635 Fever
# 636 Stomach Ache
# 637 Migraine
# 638 Shortness of Breath
# 639 Shortness of Breath
# 640 Fever
# 641 Shortness of Breath
# 642 Fever
# 643 Stomach Ache
# 644 Migraine
# 645 Stomach Ache
# 646 Migraine
# 647 Intoxication
# 648 Intoxication
# 649 Fever
# 650 Stomach Ache
# 651 Migraine
# 652 Stomach Ache
# 653 Stomach Ache
# 654 Stomach Ache
# 655 Fever
# 656 Chest Pain
# 657 Pneumonia
# 658 Pneumonia
# 659 Pneumonia
# 660 Pneumonia
# 661 Migraine
# 662 Pneumonia
# 663 Fever
# 664 Fever
# 665 Fever
# 666 Stomach Ache
# 667 Migraine
# 668 Stomach Ache
# 669 Migraine
# 670 Stomach Ache
# 671 Bleeding
# 672 Fever
# 673 Fever
# 674 Fever
# 675 Fever
# 676 Laceration
# 677 Laceration
# 678 Shortness of Breath
# 679 Shortness of Breath
# 680 Fever
# 681 Stomach Ache
# 682 Migraine
# 683 Shortness of Breath
# 684 Shortness of Breath
# 685 Fever
# 686 Shortness of Breath
# 687 Fever
# 688 Stomach Ache
# 689 Migraine
# 690 Stomach Ache
# 691 Migraine
# 692 Intoxication
# 693 Intoxication
# 694 Fever
# 695 Stomach Ache
# 696 Migraine
# 697 Stomach Ache
# 698 Stomach Ache
# 699 Stomach Ache
# 700 Fever
# 701 Chest Pain
# 702 Pneumonia
# 703 Pneumonia
# 704 Pneumonia
# 705 Pneumonia
# 706 Migraine
# 707 Pneumonia
# 708 Fever
# 709 Fever
# 710 Fever
# 711 Stomach Ache
# 712 Migraine
# 713 Stomach Ache
# 714 Migraine
# 715 Stomach Ache
# 716 Bleeding
# 717 Fever
# 718 Fever
# 719 Fever
# 720 Fever
# 721 Laceration
# 722 Laceration
# 723 Shortness of Breath
# 724 Shortness of Breath
# 725 Fever
# 726 Stomach Ache
# 727 Migraine
# 728 Shortness of Breath
# 729 Shortness of Breath
# 730 Fever
# 731 Shortness of Breath
# 732 Fever
# 733 Stomach Ache
# 734 Migraine
# 735 Stomach Ache
# 736 Migraine
# 737 Intoxication
# 738 Intoxication
# 739 Fever
# 740 Stomach Ache
# 741 Migraine
# 742 Stomach Ache
# 743 Stomach Ache
# 744 Stomach Ache
# 745 Fever
# 746 Chest Pain
# 747 Pneumonia
# 748 Pneumonia
# 749 Pneumonia
# 750 Pneumonia
# 751 Migraine
# 752 Pneumonia
# 753 Fever
# 754 Fever
# 755 Fever
# 756 Stomach Ache
# 757 Migraine
# 758 Stomach Ache
# 759 Migraine
# 760 Stomach Ache
# 761 Bleeding
# 762 Fever
# 763 Fever
# 764 Fever
# 765 Fever
# 766 Laceration
# 767 Laceration
# 768 Shortness of Breath
# 769 Shortness of Breath
# 770 Fever
# 771 Stomach Ache
# 772 Migraine
# 773 Shortness of Breath
# 774 Shortness of Breath
# 775 Fever
# 776 Shortness of Breath
# 777 Fever
# 778 Stomach Ache
# 779 Migraine
# 780 Stomach Ache
# 781 Migraine
# 782 Intoxication
# 783 Intoxication
# 784 Fever
# 785 Stomach Ache
# 786 Migraine
# 787 Stomach Ache
# 788 Stomach Ache
# 789 Stomach Ache
# 790 Fever
# 791 Chest Pain
# 792 Migraine
# 793 Pneumonia
# 794 Fever
# 795 Fever
# 796 Fever
# 797 Stomach Ache
# 798 Migraine
# 799 Stomach Ache
# 800 Migraine
# 801 Stomach Ache
# 802 Bleeding
# 803 Fever
# 804 Fever
# 805 Fever
# 806 Fever
# 807 Laceration
# 808 Laceration
# 809 Shortness of Breath
# 810 Shortness of Breath
# 811 Fever
# 812 Stomach Ache
# 813 Migraine
# 814 Shortness of Breath
# 815 Shortness of Breath
# 816 Fever
# 817 Shortness of Breath
# 818 Fever
# 819 Stomach Ache
# 820 Migraine
# 821 Stomach Ache
# 822 Migraine
# 823 Intoxication
# 824 Intoxication
# 825 Fever
# 826 Stomach Ache
# 827 Migraine
# 828 Stomach Ache
# 829 Stomach Ache
# 830 Stomach Ache
# 831 Fever
# 832 Chest Pain
# 833 Pneumonia
# 834 Pneumonia
# 835 Pneumonia
# 836 Pneumonia
# 837 Migraine
# 838 Pneumonia
# 839 Fever
# 840 Fever
# 841 Fever
# 842 Stomach Ache
# 843 Migraine
# 844 Stomach Ache
# 845 Migraine
# 846 Stomach Ache
# 847 Bleeding
# 848 Fever
# 849 Fever
# 850 Fever
# 851 Fever
# 852 Laceration
# 853 Laceration
# 854 Shortness of Breath
# 855 Shortness of Breath
# 856 Fever
# 857 Stomach Ache
# 858 Migraine
# 859 Shortness of Breath
# 860 Shortness of Breath
# 861 Fever
# 862 Shortness of Breath
# 863 Fever
# 864 Stomach Ache
# 865 Migraine
# 866 Stomach Ache
# 867 Migraine
# 868 Intoxication
# 869 Intoxication
# 870 Fever
# 871 Stomach Ache
# 872 Migraine
# 873 Stomach Ache
# 874 Stomach Ache
# 875 Stomach Ache
# 876 Fever
# 877 Chest Pain
# 878 Pneumonia
# 879 Pneumonia
# 880 Pneumonia
# 881 Pneumonia
# 882 Migraine
# 883 Pneumonia
# 884 Fever
# 885 Fever
# 886 Fever
# 887 Stomach Ache
# 888 Migraine
# 889 Stomach Ache
# 890 Migraine
# 891 Stomach Ache
# 892 Bleeding
# 893 Fever
# 894 Fever
# 895 Fever
# 896 Fever
# 897 Laceration
# 898 Laceration
# 899 Shortness of Breath
# 900 Shortness of Breath
# 901 Fever
# 902 Stomach Ache
# 903 Migraine
# 904 Shortness of Breath
# 905 Shortness of Breath
# 906 Fever
# 907 Shortness of Breath
# 908 Fever
# 909 Stomach Ache
# 910 Migraine
# 911 Stomach Ache
# 912 Migraine
# 913 Intoxication
# 914 Intoxication
# 915 Fever
# 916 Stomach Ache
# 917 Migraine
# 918 Stomach Ache
# 919 Stomach Ache
# 920 Stomach Ache
# 921 Fever
# 922 Chest Pain
# 923 Pneumonia
# 924 Pneumonia
# 925 Migraine
# 926 Pneumonia
# 927 Fever
# 928 Fever
# 929 Fever
# 930 Stomach Ache
# 931 Migraine
# 932 Stomach Ache
# 933 Migraine
# 934 Stomach Ache
# 935 Bleeding
# 936 Fever
# 937 Fever
# 938 Fever
# 939 Fever
# 940 Laceration
# 941 Laceration
# 942 Shortness of Breath
# 943 Shortness of Breath
# 944 Fever
# 945 Stomach Ache
# 946 Migraine
# 947 Shortness of Breath
# 948 Shortness of Breath
# 949 Fever
# 950 Shortness of Breath
# 951 Fever
# 952 Stomach Ache
# 953 Migraine
# 954 Stomach Ache
# 955 Migraine
# 956 Intoxication
# 957 Intoxication
# 958 Fever
# 959 Stomach Ache
# 960 Migraine
# 961 Stomach Ache
# 962 Stomach Ache
# 963 Stomach Ache
# 964 Fever
# 965 Chest Pain
# 966 Pneumonia
# 967 Pneumonia
# 968 Pneumonia
# 969 Pneumonia
# 970 Migraine
# 971 Pneumonia
# 972 Fever
# 973 Fever
# 974 Fever
# 975 Stomach Ache
# 976 Migraine
# 977 Stomach Ache
# 978 Migraine
# 979 Stomach Ache
# 980 Bleeding
# 981 Fever
# 982 Fever
# 983 Fever
# 984 Fever
# 985 Laceration
# 986 Laceration
# 987 Shortness of Breath
# 988 Shortness of Breath
# 989 Fever
# 990 Stomach Ache
# 991 Migraine
# 992 Shortness of Breath
# 993 Shortness of Breath
# 994 Fever
# 995 Shortness of Breath
# 996 Fever
# 997 Stomach Ache
# 998 Migraine
# 999 Stomach Ache
# 1000 Migraine
# 1001 Intoxication
# 1002 Intoxication
# 1003 Fever
# 1004 Stomach Ache
# 1005 Migraine
# 1006 Stomach Ache
# 1007 Stomach Ache
# 1008 Stomach Ache
# 1009 Fever
# 1010 Chest Pain
# 1011 Pneumonia
# 1012 Migraine
# 1013 Pneumonia
# 1014 Fever
# 1015 Fever
# 1016 Fever
# 1017 Stomach Ache
# 1018 Migraine
# 1019 Stomach Ache
# 1020 Migraine
# 1021 Stomach Ache
# 1022 Bleeding
# 1023 Fever
# 1024 Fever
# 1025 Fever
# 1026 Fever
# 1027 Laceration
# 1028 Laceration
# 1029 Shortness of Breath
# 1030 Shortness of Breath
# 1031 Fever
# 1032 Stomach Ache
# 1033 Migraine
# 1034 Shortness of Breath
# 1035 Shortness of Breath
# 1036 Fever
# 1037 Shortness of Breath
# 1038 Fever
# 1039 Stomach Ache
# 1040 Migraine
# 1041 Stomach Ache
# 1042 Migraine
# 1043 Intoxication
# 1044 Intoxication
# 1045 Fever
# 1046 Stomach Ache
# 1047 Migraine
# 1048 Stomach Ache
# 1049 Stomach Ache
# 1050 Stomach Ache
# 1051 Fever
# 1052 Chest Pain
# 1053 Pneumonia
# 1054 Pneumonia
# 1055 Pneumonia
# 1056 Pneumonia
# 1057 Migraine
# 1058 Pneumonia
# 1059 Fever
# 1060 Fever
# 1061 Fever
# 1062 Stomach Ache
# 1063 Migraine
# 1064 Stomach Ache
# 1065 Migraine
# 1066 Stomach Ache
# 1067 Bleeding
# 1068 Fever
# 1069 Fever
# 1070 Fever
# 1071 Fever
# 1072 Laceration
# 1073 Laceration
# 1074 Shortness of Breath
# 1075 Shortness of Breath
# 1076 Fever
# 1077 Stomach Ache
# 1078 Migraine
# 1079 Shortness of Breath
# 1080 Shortness of Breath
# 1081 Fever
# 1082 Shortness of Breath
# 1083 Fever
# 1084 Stomach Ache
# 1085 Migraine
# 1086 Stomach Ache
# 1087 Migraine
# 1088 Intoxication
# 1089 Intoxication
# 1090 Fever
# 1091 Stomach Ache
# 1092 Migraine
# 1093 Stomach Ache
# 1094 Stomach Ache
# 1095 Stomach Ache
# 1096 Fever
# 1097 Chest Pain
# 1098 Pneumonia
# 1099 Migraine
# 1100 Pneumonia
# 1101 Fever
# 1102 Fever
# 1103 Fever
# 1104 Stomach Ache
# 1105 Migraine
# 1106 Stomach Ache
# 1107 Migraine
# 1108 Stomach Ache
# 1109 Bleeding
# 1110 Fever
# 1111 Fever
# 1112 Fever
# 1113 Fever
# 1114 Laceration
# 1115 Laceration
# 1116 Shortness of Breath
# 1117 Shortness of Breath
# 1118 Fever
# 1119 Stomach Ache
# 1120 Migraine
# 1121 Shortness of Breath
# 1122 Shortness of Breath
# 1123 Fever
# 1124 Shortness of Breath
# 1125 Fever
# 1126 Stomach Ache
# 1127 Migraine
# 1128 Stomach Ache
# 1129 Migraine
# 1130 Intoxication
# 1131 Intoxication
# 1132 Fever
# 1133 Stomach Ache
# 1134 Migraine
# 1135 Stomach Ache
# 1136 Stomach Ache
# 1137 Stomach Ache
# 1138 Fever
# 1139 Chest Pain
# 1140 Pneumonia
# 1141 Pneumonia
# 1142 Pneumonia
# 1143 Pneumonia
# 1144 Migraine
# 1145 Pneumonia
# 1146 Fever
# 1147 Fever
# 1148 Fever
# 1149 Stomach Ache
# 1150 Migraine
# 1151 Stomach Ache
# 1152 Migraine
# 1153 Stomach Ache
# 1154 Migraine
# 1155 Pneumonia
# 1156 Fever
# 1157 Fever
# 1158 Fever
# 1159 Stomach Ache
# 1160 Migraine
# 1161 Stomach Ache
# 1162 Migraine
# 1163 Stomach Ache
# 1164 Bleeding
# 1165 Fever
# 1166 Fever
# 1167 Fever
# 1168 Fever
# 1169 Laceration
# 1170 Laceration
# 1171 Shortness of Breath
# 1172 Shortness of Breath
# 1173 Fever
# 1174 Stomach Ache
# 1175 Migraine
# 1176 Shortness of Breath
# 1177 Shortness of Breath
# 1178 Fever
# 1179 Shortness of Breath
# 1180 Fever
# 1181 Stomach Ache
# 1182 Migraine
# 1183 Stomach Ache
# 1184 Migraine
# 1185 Intoxication
# 1186 Intoxication
# 1187 Fever
# 1188 Stomach Ache
# 1189 Migraine
# 1190 Stomach Ache
# 1191 Stomach Ache
# 1192 Stomach Ache
# 1193 Fever
# 1194 Chest Pain
# 1195 Pneumonia
# 1196 Pneumonia
# 1197 Pneumonia
# 1198 Pneumonia

# %% [markdown]
# <span style="color:  #00008B;"> Qs 46: Count of canceled status. </span>

# %%
canceled_status = len(df_AmbV[df_AmbV['VisitStatus'] == 'Canceled'])

print("Number of patients whose visit status are canceled: ",canceled_status)
# Out:
# Number of patients whose visit status are canceled:  60

# %% [markdown]
# <span style="color:#00008B;"> Qs 47: Display the patient details with maximum pulse pressure. </span>

# %%
#max_pulse = df_AmbV[df_AmbV['Pulse']].groupby('Patient_ID').max().index()
#max_pulse= df_AmbV.loc[df_AmbV['Pulse'].idxmax()]
max_pulse = df_AmbV.groupby(['PatientMRN'], as_index=True)['Pulse'].max()
max_pulse.max()
# Out:
# 99.98646314

# %% [markdown]
# <span style="color:#00008B;"> Qs 48:  Create a heat map to show the correlation between the column values of Edvisits. </span>

# %%
import seaborn as sns
df_ED = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "EDVisits")
df_ED.corr()
sns.heatmap(df_ED.corr());
sns.heatmap(df_ED.corr()).set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
sns.heatmap(df_ED.corr(), vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Heatmap'}>

# %% [markdown]
# <span style="color:#00008B;"> Qs 49:  Plot a graph by counting the no. of patients in each department. </span>

# %%
PI=sns.countplot(x='VisitDepartmentID',data=df_AmbV)
PI.bar_label(PI.containers[0],label_type='edge')
plt.title('No. of Patients Visited the Department')
plt.xlabel('Department ID') and plt.ylabel('No of Patients')

plt.show()

# %% [markdown]
# <span style="color:#00008B;"> Qs 50:  Display patient details where "ReasonForVisit" is either 'Migraine' or 'Pneumonia' and Acuity is 2 or more. </span>

# %%
reasonforvisit = df_ED[['PatientID', 'ReasonForVisit', 'Acuity']].loc[((df_ED['ReasonForVisit'] == 'Migraine') | (df_ED['ReasonForVisit'] == 'Pneumonia')) & (df_ED['Acuity'] >= 2)]
reasonforvisit
# Out:
#       PatientID ReasonForVisit  Acuity
# 1          12.0       Migraine     2.0
# 3          14.0       Migraine     3.0
# 11         29.0      Pneumonia     2.0
# 12         30.0      Pneumonia     3.0
# 13         31.0      Pneumonia     4.0
# ...         ...            ...     ...
# 1107      773.0       Migraine     2.0
# 1150      850.0       Migraine     2.0
# 1152      852.0       Migraine     2.0
# 1160      868.0       Migraine     2.0
# 1162      870.0       Migraine     2.0
#
# [215 rows x 3 columns]

# %% [markdown]
# <span style="color:#00008B;"> Qs 51:  Take the ReasonForVisit from user, find the number of patients admitted with that ReasonForVisit. </span>

# %%
# givenWord =input("Reason for the visit = ")
# df_ED = pd.read_excel("HospitalDatabase.xlsx",usecols=['ReasonForVisit'], sheet_name = "EDVisits")
# count=0
# for index,row in df_ED.iterrows():
#     if(row.values == givenWord):
#         count=count+1
# print(count)

# %%
# #looooop works 
# try:
#     var1 = input("Reason for visit:")
#     df_ED = pd.read_excel("HospitalDatabase.xlsx",usecols=['ReasonForVisit'], sheet_name = "EDVisits")
#     for patient_id, reasonforvisit in df_ED.iterrows():
#         df_ED.loc['Reason For Visit'].groupby('PatientID').count.sort_values(by = 'EDDisposition', ascending = False)
#     raise "Inside loop"
# except faultyloop:
#     print("out of loop")
# else:
#     print("unsuccessfull")

# %%
# var1 = input("Reason for visit:")
# df_ED = pd.read_excel("HospitalDatabase.xlsx",usecols=['ReasonForVisit'], sheet_name = "EDVisits")
# count=0
# for patient_id, reasonforvisit in df_ED.iterrows():
#     if df_ED[df_ED] df_ED.loc['Reason For Visit'].groupby('PatientID').count.sort_values(by = 'EDDisposition', ascending = False)
#        break 
# print(df_ED)

# %%
# for x in languages:
#     print("------")
#     for lang in x:
#         if lang == "German":
#             continue
#         print(lang)

# %%
# ptions = ['Commerce' ,'Science'] 
    
# # selecting rows based on condition 
# rslt_df = dataframe[(dataframe['Age'] == 22) & 
#           dataframe['Stream'].isin(options)] 
    
# print('\nResult dataframe :\n',
#       rslt_df)

# %% [markdown]
# <span style="color:#00008B;"> Qs 52  Using indexing , loc to retrieve the row with maximum BloodPressureSystolic. </span>

# %%
df_AmbV.loc[df_AmbV[df_AmbV['BloodPressureSystolic']==df_AmbV['BloodPressureSystolic'].max()].index]
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 236    933.0       884.0        27.0  2019-02-14 2019-01-22 19:26:49.163
# 251    888.0       906.0        24.0  2019-03-31 2019-03-17 23:21:17.361
# 424    314.0        63.0         7.0  2019-04-05 2019-03-24 22:31:26.092
# 432    740.0       892.0        31.0  2019-03-14 2019-03-11 15:08:33.963
# 677    929.0       880.0        23.0  2019-02-10 2019-01-22 13:32:14.549
# 869    839.0       857.0        12.0  2019-03-17 2019-02-23 09:05:43.676
# 934    482.0       866.0        14.0  2019-05-04 2019-04-13 07:54:49.580
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 236               12.0  Telemedicine                  190.0
# 251               10.0           New                  190.0
# 424               11.0  Telemedicine                  190.0
# 432                8.0      Physical                  190.0
# 677                8.0     Follow Up                  190.0
# 869                8.0     Follow Up                  190.0
# 934                5.0           New                  190.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 236              143.989174  74.976879   Completed
# 251              137.207999  52.666922   Completed
# 424              121.539859  95.471260   Completed
# 432              145.343479  94.849021   Completed
# 677              144.313400  82.781940   Completed
# 869              130.997386  71.829542   Completed
# 934              124.736359  69.731779    Canceled

# %% [markdown]
# <span style="color:#00008B;"> Qs 53: Plot a graph by multiplotting on the same canvas . </span>

# %%
x =np.arange(0,10,0.5) 
y1 = x*x
y2= x*x*x
y3= -1*x
y4= -x*x +20
fig, axes = plt.subplots(2, 2)  
axes[0, 0].plot(x, y1, '-') 
axes[0, 1].plot(x, y2, 'm--o') 
axes[1, 0].plot(x, y3, 'b--o') 
axes[1, 1].plot(x, y4, 'r--o')

# %% [markdown]
# <span style="color:#00008B;"> Qs 54: Retrieve the row with minimum DBP using sorting technique. </span>

# %%
df_AmbV.sort_values("BloodPressureDiastolic", ascending=True).head(1)
#df_AmbV.nsmallest(1, "BloodPressureDiastolic") (#smallest value function)
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 757    163.0       801.0        11.0  2019-02-08 2019-02-07 23:41:12.181
#
#      VisitDepartmentID  VisitType  BloodPressureSystolic  \
# 757                7.0  Follow Up                  120.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 757               51.695653  53.310495   Completed

# %% [markdown]
# <span style="color:#00008B;">Qs 55: Replace all the null values in ReadmissionFlag with 0. </span>

# %%
df_ReAd = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "ReAdmissionRegistry")
df_ReAd.fillna(value = 0,inplace = True)
# Show the DataFrame
df_ReAd.head()
# Out:
#    AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0        389.0        1.0    2018-01-01 2018-01-04 19:59:31.391
# 1        635.0        2.0    2018-01-01 2018-01-04 21:28:51.898
# 2        606.0        3.0    2018-01-01 2018-01-04 22:28:23.672
# 3        587.0        5.0    2018-01-01 2018-01-05 05:47:04.933
# 4        640.0        6.0    2018-01-01 2018-01-05 14:18:30.029
#
#   DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                 Home       Hospitalist   Kidney Failure     6.717771
# 1                 Home  General Medicine              Flu     3.825969
# 2                 Home  General Medicine              Flu     3.382493
# 3                 Home  General Medicine              Flu     3.763352
# 4                 Home               ICU    Heart Failure    13.650953
#
#    ExpectedMortality  ReadmissionFlag  DaysToReadmission  \
# 0           0.010046              0.0                0.0
# 1           0.604562              1.0                2.0
# 2           0.266137              1.0                3.0
# 3           0.307527              1.0                4.0
# 4           0.408898              0.0                0.0
#
#    EDVisitAfterDischargeFlag
# 0                        0.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        0.0

# %% [markdown]
# <span style="color:#00008B;">Qs 56: Get the list of patient ID's which are not there in ReadmissionRegistry. </span>

# %%
#df = df[~((df['id'] == 1) & df['value'].isna())]
df_ReAd = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "ReAdmissionRegistry")
not_readmitted = df_ReAd[df_ReAd['ReadmissionFlag']].count().sort_values(by = 'PatientID', ascending = False)
print(not_readmitted)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 #df = df[~((df['id'] == 1) & df['value'].isna())]
#       2 df_ReAd = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "ReAdmissionRegistry")
# ----> 3 not_readmitted = df_ReAd[df_ReAd['ReadmissionFlag']].count().sort_values(by = 'PatientID', ascending = False)
#       4 print(not_readmitted)
#
# File C:\anaco\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File C:\anaco\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File C:\anaco\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Float64Index([nan, 1.0, 1.0, 1.0, nan, 1.0, 1.0, nan, 1.0, 1.0,\n              ...\n              1.0, nan, nan, 1.0, nan, nan, nan, nan, nan, nan],\n             dtype='float64', length=720)] are in the [columns]"

# %% [markdown]
# <span style="color:#00008B;">Qs 57: Find reasonForVisit with highest count of acuity 5 patients. </span>

# %%
dq1= df_ED[df_ED['Acuity']==5]
max_acuity = dq1.groupby(df_ED['ReasonForVisit']).count().sort_values(by = 'Acuity', ascending = False)
max_acuity.head(1)

# %% [markdown]
# <span style="color:#00008B;">Qs 58: Display full name of patients who are born in 1986.</span>

# %%
patient_details = pd.DataFrame(df_PA[['FirstName','LastName','DateOfBirth']])

#Combining fullname in a single column
patient_details['FullName'] = patient_details[['FirstName','LastName']].apply(lambda x: ' '.join(x), axis=1)

#To extract year of birth from DOB
patient_details['YearOfBirth'] = pd.DatetimeIndex(patient_details['DateOfBirth']).year

# Display full name of patients who born in 1986
patient_DOB_1986= patient_details[patient_details['YearOfBirth'] == 1986][['FullName','YearOfBirth']]
print('There are 26 patients born in 1986')
patient_DOB_1986

# %% [markdown]
# <span style="color:#00008B;">Qs 59:Create a bar chart by making list on Acuity & EDDisposition column (with no duplicates) & make the hatchs onto the bar by using set_hatch() method.</span>

# %%
import seaborn as sns
import numpy as np
df_ED = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "EDVisits")
sns.barplot(y='Acuity',x='EDDisposition', palette = 'Pastel1', hatch='/o*',data=df_ED);

# %% [markdown]
# <span style="color:#00008B;"> Qs 60:Create a heat map on Readmission Registry table to find correlation between columns values.</span>

# %%
# import seaborn as sns
# df_ReAd = pd.read_excel("HospitalDatabase.xlsx", sheet_name = "ReAdmissionRegistry")
df_ReAd.corr()
sns.heatmap(df_ReAd.corr());
sns.heatmap(df_ReAd.corr()).set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
sns.heatmap(df_ReAd.corr(), vmin=-1, vmax=1, annot=True)
